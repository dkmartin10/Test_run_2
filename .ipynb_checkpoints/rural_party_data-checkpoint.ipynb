# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows',5000)
pd.set_option('display.max_columns',5000)

# %%
# master_sheet = pd.read_excel('rural_party_data.xlsx')
# per_pop_rural = pd.read_excel('rural_party_data.xlsx',sheet_name = 'Per Pop Rural')
# counts = pd.read_excel('rural_party_data.xlsx',sheet_name = 'Counts')
county_chairs = pd.read_excel('rural_party_data.xlsx',sheet_name = 'County Chairs')
# sub_county_pops = pd.read_excel('rural_party_data.xlsx',sheet_name = 'Sub County Pops')

# %%
county_chairs.head()
# Out:
#                        County State                   County, State District  \
# 0      Aleutians East Borough    AK      Aleutians East Borough, AK      NaN
# 1  Aleutians West Census Area    AK  Aleutians West Census Area, AK      NaN
# 2      Anchorage Municipality    AK      Anchorage Municipality, AK      NaN
# 3          Bethel Census Area    AK          Bethel Census Area, AK      NaN
# 4         Bristol Bay Borough    AK         Bristol Bay Borough, AK      NaN
#
#   Democratic Chairperson Email Phone
# 0                    NaN   NaN   NaN
# 1                    NaN   NaN   NaN
# 2                    NaN   NaN   NaN
# 3                    NaN   NaN   NaN
# 4                    NaN   NaN   NaN

# %%
# Out:
#                               County State  \
# 0             Aleutians East Borough    AK
# 1         Aleutians West Census Area    AK
# 2             Anchorage Municipality    AK
# 3                 Bethel Census Area    AK
# 4                Bristol Bay Borough    AK
# 5                     Denali Borough    AK
# 6             Dillingham Census Area    AK
# 7       Fairbanks North Star Borough    AK
# 8                     Haines Borough    AK
# 9          Hoonah-Angoon Census Area    AK
# 10           Juneau City and Borough    AK
# 11           Kenai Peninsula Borough    AK
# 12         Ketchikan Gateway Borough    AK
# 13             Kodiak Island Borough    AK
# 14              Kusilvak Census Area    AK
# 15        Lake and Peninsula Borough    AK
# 16         Matanuska-Susitna Borough    AK
# 17                  Nome Census Area    AK
# 18               North Slope Borough    AK
# 19          Northwest Arctic Borough    AK
# 20            Petersburg Census Area    AK
# 21  Price of Wales Hyder Census Area    AK
# 22            Sitka City and Borough    AK
# 23              Skagway Municipality    AK
# 24   Southeast Fairbanks Census Area    AK
# 25        Valdez-Cordova Census Area    AK
# 26         Wrangell City and Borough    AK
# 27          Yakutat City and Borough    AK
# 28         Yukon-Koyukuk Census Area    AK
# 29                         Anchorage    AK
# 30                 Matanuska-Susitna    AK
#
#                            County, State District Democratic Chairperson  \
# 0             Aleutians East Borough, AK      NaN                    NaN
# 1         Aleutians West Census Area, AK      NaN                    NaN
# 2             Anchorage Municipality, AK      NaN                    NaN
# 3                 Bethel Census Area, AK      NaN                    NaN
# 4                Bristol Bay Borough, AK      NaN                    NaN
# 5                     Denali Borough, AK      NaN                    NaN
# 6             Dillingham Census Area, AK      NaN                    NaN
# 7       Fairbanks North Star Borough, AK      NaN                    NaN
# 8                     Haines Borough, AK      NaN                    NaN
# 9          Hoonah-Angoon Census Area, AK      NaN                    NaN
# 10           Juneau City and Borough, AK      NaN                    NaN
# 11           Kenai Peninsula Borough, AK      NaN                    NaN
# 12         Ketchikan Gateway Borough, AK      NaN                    NaN
# 13             Kodiak Island Borough, AK      NaN                    NaN
# 14              Kusilvak Census Area, AK      NaN                    NaN
# 15        Lake and Peninsula Borough, AK      NaN                    NaN
# 16         Matanuska-Susitna Borough, AK      NaN                    NaN
# 17                  Nome Census Area, AK      NaN                    NaN
# 18               North Slope Borough, AK      NaN                    NaN
# 19          Northwest Arctic Borough, AK      NaN                    NaN
# 20            Petersburg Census Area, AK      NaN                    NaN
# 21  Price of Wales Hyder Census Area, AK      NaN                    NaN
# 22            Sitka City and Borough, AK      NaN                    NaN
# 23              Skagway Municipality, AK      NaN                    NaN
# 24   Southeast Fairbanks Census Area, AK      NaN                    NaN
# 25        Valdez-Cordova Census Area, AK      NaN                    NaN
# 26         Wrangell City and Borough, AK      NaN                    NaN
# 27          Yakutat City and Borough, AK      NaN                    NaN
# 28         Yukon-Koyukuk Census Area, AK      NaN                    NaN
# 29                         Anchorage, AK      NaN        Michelle Turner
# 30                 Matanuska-Susitna, AK      NaN            Pat Chesbro
#
#                      Email         Phone
# 0                      NaN           NaN
# 1                      NaN           NaN
# 2                      NaN           NaN
# 3                      NaN           NaN
# 4                      NaN           NaN
# 5                      NaN           NaN
# 6                      NaN           NaN
# 7                      NaN           NaN
# 8                      NaN           NaN
# 9                      NaN           NaN
# 10                     NaN           NaN
# 11                     NaN           NaN
# 12                     NaN           NaN
# 13                     NaN           NaN
# 14                     NaN           NaN
# 15                     NaN           NaN
# 16                     NaN           NaN
# 17                     NaN           NaN
# 18                     NaN           NaN
# 19                     NaN           NaN
# 20                     NaN           NaN
# 21                     NaN           NaN
# 22                     NaN           NaN
# 23                     NaN           NaN
# 24                     NaN           NaN
# 25                     NaN           NaN
# 26                     NaN           NaN
# 27                     NaN           NaN
# 28                     NaN           NaN
# 29  mtturner92@outlook.com  907 351 6342
# 30   chesbro@mtaonline.net  907 232 3712

# %%
# Out:
#                   County State           County, State District  \
# 157                 Pope    AR                Pope, AR      NaN
# 1351              Alcona    MI              Alcona, MI      NaN
# 1421        Presque Isle    MI        Presque Isle, MI      NaN
# 1990  Grafton - Northern    NH  Grafton - Northern, NH      NaN
# 2607             Hopkins    TX             Hopkins, TX      NaN
# 2609             Houston    TX             Houston, TX      NaN
# 2611              Howard    TX              Howard, TX      NaN
# 2613            Hudspeth    TX            Hudspeth, TX      NaN
#
#           Democratic Chairperson                         Email  \
# 157                          NaN                           NaN
# 1351                         NaN                           NaN
# 1421                         NaN                           NaN
# 1990  Betsey Phillips (Co-chair)                  603-869-0127
# 2607                  Tommy Long           tlong@circlelcc.com
# 2609                Sharon Berry  seberryhoustoncnty@gmail.com
# 2611                Ben Zeichick        bigspringben@yahoo.com
# 2613                  Dee Torres       deetorres1950@gmail.com
#
#                    Phone
# 157                  NaN
# 1351                 NaN
# 1421                 NaN
# 1990  bphill36@gmail.com
# 2607        903-945-2142
# 2609        936-438-1234
# 2611        941-875-1729
# 2613                 NaN

# %%
county_chairs[county_chairs['County'].str.contains('Saint')]
# Out:
#                 County State         County, State District  \
# 88         Saint Clair    AL       Saint Clair, AL      NaN
# 1525  Sainte Genevieve    MO  Sainte Genevieve, MO      NaN
#
#      Democratic Chairperson                      Email         Phone
# 88             Niesha Brown                        NaN           NaN
# 1525            Robert Lord  hodakarider.rl1@gmail.com  573-880-2294

# %%
county_chairs['County'].replace(['^Saint[a-z]*', '^Sainte[a-z]*'], 'St.', regex = True, inplace = True)
county_chairs['County, State'].replace(['^Saint[a-z]*', '^Sainte[a-z]*'], 'St.', regex = True, inplace = True)

# %%
county_chairs.iloc[1525]
# Out:
# County                                St. Genevieve
# State                                            MO
# County, State                     St. Genevieve, MO
# District                                        NaN
# Democratic Chairperson                  Robert Lord
# Email                     hodakarider.rl1@gmail.com
# Phone                                  573-880-2294
# Name: 1525, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d903716c076f> in <module>
# ----> 1 master_sheet.head()
#
# NameError: name 'master_sheet' is not defined

# %%
master_sheet[master_sheet['County'].str.contains('Saint')]

# %%
# git testing the commit
