# %%
import pandas as pd
import numpy as np
import re

# %%
pd.set_option('display.max_rows',5000)
pd.set_option('display.max_columns',5000)

# %%
master_sheet = pd.read_excel('rural_party_data.xlsx')
# per_pop_rural = pd.read_excel('rural_party_data.xlsx',sheet_name = 'Per Pop Rural')
# counts = pd.read_excel('rural_party_data.xlsx',sheet_name = 'Counts')
county_chairs = pd.read_excel('rural_party_data.xlsx',sheet_name = 'County Chairs')
# sub_county_pops = pd.read_excel('rural_party_data.xlsx',sheet_name = 'Sub County Pops')

# %%
master_sheet['State'].unique()
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'], dtype=object)

# %%
county_chairs[county_chairs['County'].str.contains('District')]
# Out:
#                         County State                 County, State District  \
# 312               1st District    CT              1st District, CT      NaN
# 313               2nd District    CT              2nd District, CT      NaN
# 314               3rd District    CT              3rd District, CT      NaN
# 315               4th District    CT              4th District, CT      NaN
# 316               5th District    CT              5th District, CT      NaN
# 317               6th District    CT              6th District, CT      NaN
# 318               7th District    CT              7th District, CT      NaN
# 319               8th District    CT              8th District, CT      NaN
# 320               9th District    CT              9th District, CT      NaN
# 321              10th District    CT             10th District, CT      NaN
# 322              11th District    CT             11th District, CT      NaN
# ...

# %%
county_chairs[county_chairs['County'].str.contains('St ')]
# Out:
#                           County State                   County, State  \
# 167                   St Francis    AR                  St Francis, AR
# 825                     St Clair    IL                    St Clair, IL
# 916                    St Joseph    IN                   St Joseph, IN
# 1190                  St Bernard    LA                  St Bernard, LA
# 1191                  St Charles    LA                  St Charles, LA
# 1192                   St Helena    LA                   St Helena, LA
# 1193                    St James    LA                    St James, LA
# 1194                   St Landry    LA                   St Landry, LA
# 1195                   St Martin    LA                   St Martin, LA
# 1196                     St Mary    LA                     St Mary, LA
# 1197                  St Tammany    LA                  St Tammany, LA
# 1252           St Bernard Parish    LA           St Bernard Parish, LA
# ...

# %%
# county_chairs['County'].replace(['^Saint[a-z]*', '^Sainte[a-z]*'], 'St.', regex = True, inplace = True)
# county_chairs['County, State'].replace(['^Saint[a-z]*', '^Sainte[a-z]*'], 'St.', regex = True, inplace = True)

# %%
def St(df):
    df['County'].replace(['^Saint[a-z]*', '^Sainte[a-z]*','\b^St+\s\b'], 'St.', regex = True, inplace = True)
    df['County, State'].replace(['^Saint[a-z]*', '^Sainte[a-z]*','\b^St+\s\b'], 'St.', regex = True, inplace = True)

# %%
St(county_chairs)

# %%
county_chairs.iloc[1507]
# Out:
# County                        St Louis
# State                               MN
# County, State             St Louis, MN
# District                           NaN
# Democratic Chairperson             NaN
# Email                              NaN
# Phone                              NaN
# Name: 1507, dtype: object

# %%
county_chairs.iloc[88]
# Out:
# County                        St. Clair
# State                                AL
# County, State             St. Clair, AL
# District                            NaN
# Democratic Chairperson     Niesha Brown
# Email                               NaN
# Phone                               NaN
# Name: 88, dtype: object

# %%
dup = county_chairs.duplicated(subset = ['County, State','Email'],keep=False)
print(county_chairs[dup])
# Out:
#         County State County, State District Democratic Chairperson  \
# 98        Pope    AR      Pope, AR      NaN             Chad Easly
# 157       Pope    AR      Pope, AR      NaN                    NaN
# 2606   Hopkins    TX   Hopkins, TX      NaN             Tommy Long
# 2607   Hopkins    TX   Hopkins, TX      NaN             Tommy Long
# 2608   Houston    TX   Houston, TX      NaN           Sharon Berry
# 2609   Houston    TX   Houston, TX      NaN           Sharon Berry
# 2610    Howard    TX    Howard, TX      NaN           Ben Zeichick
# 2611    Howard    TX    Howard, TX      NaN           Ben Zeichick
# 2612  Hudspeth    TX  Hudspeth, TX      NaN             Dee Torres
# 2613  Hudspeth    TX  Hudspeth, TX      NaN             Dee Torres
#
#                              Email         Phone
# 98                             NaN  479 886 1966
# 157                            NaN           NaN
# 2606           tlong@circlelcc.com  903-945-2142
# ...
